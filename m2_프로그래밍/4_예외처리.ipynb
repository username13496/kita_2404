# %% [markdown]
# ## 에러(Error) vs. 예외(Exception).
#
# 에러(Error): 코드 잘못 침(오타) 같은거/코드를 바꿔야 함
# - 에러는 주로 프로그램 실행 전에 발생하는, 프로그램의 잘못된 구문이나 절차 등에 의해 발생하는 문제를 말한다.
# - 대표적인 에러로는 구문 에러(SyntaxError)가 있다. 예를 들어, 올바르지 않은 들여쓰기나 잘못된 코드 구조로 인해 파이썬 인터프리터가 코드를 실행하기 전에 에러를 발생시킨다.
# - 에러는 대체로 프로그램의 수정 없이는 복구될 수 없는 심각한 문제들이다.
#
# 예외(Exception): 정수 입력인데 실수나 기호 입력
# - 예외는 실행 중인 프로그램에 영향을 주는 이벤트로, 일반적인 프로그램 흐름을 방해한다.
# - 예외는 프로그램의 정상적인 흐름을 방해하지만, 적절한 예외 처리를 통해 프로그램의 중단 없이 예외를 '잡아내고(catch)' 처리할 수 있다. 예를 들어, 파일을 열 때 파일이 존재하지 않는 경우 FileNotFoundError 예외가 발생할 수 있다. 이 경우 적절한 except 블록으로 예외를 처리하여 사용자에게 메시지를 표시하고 대안적인 행동을 취할 수 있다.
# - 예외는 try-except 블록을 통해 프로그램에서 처리할 수 있으며, 이를 통해 프로그램이 예외 상황에서도 안정적으로 동작하도록 만들 수 있다.
#
# 요약하자면, 에러는 대개 코드 수정이 필요한 문제들을 가리키며, 예외는 프로그램 실행 중에 발생하지만 적절히 처리할 수 있는 예상 가능한 '예외적' 상황들을 말한다.

# %% [markdown]
# #### 파이썬에서 발생할 수 있는 에러와 예외의 유형:
# 에러 : 프로그램이 실행되기 전에 발생하는 문제
# - SyntaxError: 코드의 구문이 잘못되었을 때 생긴다.<br>
#
# 예외 : 실행 시간(runtime) 중에 발생하고 처리 가능
# - NameError: 정의되지 않은 변수를 호출할 때 생긴다.
# - TypeError: 연산이나 함수가 부적절한 유형의 객체에 적용될 때 발생한다. 객체
# - ValueError: 연산이나 함수가 적절하지 않은 값을 객체에 적용할 때 발생한다. 값
# - IndexError: 리스트 등의 시퀀스에서 존재하지 않는 인덱스를 사용할 때 생긴다. 인덱스 범위 벗어남(Out of range)
# - KeyError: 딕셔너리에서 존재하지 않는 키를 사용할 때 발생한다. 없는 키
# - AttributeError: 존재하지 않는 속성이나 메서드를 호출할 때 생긴다. 없는 속성/메서드
# - IOError 또는 OSError: 파일 입출력 과정에서 에러가 생길 때 발생한다.
# - ZeroDivisionError: 0으로 나눌 때 생긴다. 0
# - ImportError: 모듈을 임포트할 수 없을 때 발생한다. 없는 모듈
# - StopIteration: 이터레이터에 더 이상의 아이템이 없을 때 next()를 호출하면 발생한다. 반복불가
# - MemoryError: 메모리 할당이 실패할 때 생긴다.
# - RecursionError: 재귀 호출이 너무 깊어질 때 발생한다.

# %%
# 구문 오류 : 프로그램 실행전에 발생하는 오류
# 예외 또는 런타임 오류 : 프로그램 실행중에 발생하는 오류

print('강제 예외 발생) # 코드를 봐야함
# Out:
#   File "<ipython-input-1-0dd834f584b0>", line 4
#     print('강제 예외 발생) # 코드를 봐야함
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# SyntaxError : 잘못된 구문
for i in range(10)
  print(i)
# Out:
#   File "<ipython-input-2-f256dfdf4732>", line 2
#     for i in range(10)
#                       ^
# SyntaxError: expected ':'

# %%
# NameError: 정의되지 않은 변수 사용
# unknown_var = 42
print(unknown_var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d2f942231c2> in <cell line: 3>()
#       1 # NameError: 정의되지 않은 변수 사용
#       2 # unknown_var = 42
# ----> 3 print(unknown_var)
#
# NameError: name 'unknown_var' is not defined

# %%
# 정수를 입력하지 않은 경우 예외 발생
num_input = int(input('정수 입력 > '))
print('반지름 : ', num_input)
# Out:
# 정수 입력 > ㄷ
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-790bfe5eb620> in <cell line: 2>()
#       1 # 정수를 입력하지 않은 경우 예외 발생
# ----> 2 num_input = int(input('정수 입력 > '))
#       3 print('반지름 : ', num_input)
#
# ValueError: invalid literal for int() with base 10: 'ㄷ'

# %%
# TypeError :  부적절한 유형의 객체 연산
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d50e7b78fc89> in <cell line: 2>()
#       1 # TypeError :  부적절한 유형의 객체 연산
# ----> 2 '2' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
# ValueError : 적절하지 않은 값 사용
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f55536014fc4> in <cell line: 2>()
#       1 # ValueError : 적절하지 않은 값 사용
# ----> 2 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
# IndexError : 존재하지 않는 인덱스 사용
my_li = [1,2,3]
print(my_li[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-8a9a3940565c> in <cell line: 3>()
#       1 # IndexError : 존재하지 않는 인덱스 사용
#       2 my_li = [1,2,3]
# ----> 3 print(my_li[3])
#
# IndexError: list index out of range

# %%
# KeyError :  딕셔너리에서 존재하지 않는 키 사용
my_dict = {'a':1,'b':2}
print(my_dict['c'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-9ca21ccaf8f2> in <cell line: 3>()
#       1 # KeyError :  딕셔너리에서 존재하지 않는 키 사용
#       2 my_dict = {'a':1,'b':2}
# ----> 3 print(my_dict['c'])
#
# KeyError: 'c'

# %%
# AttributeError: 존재하지 않는 속성이나 메서드를 호출 리스트엔 push라는 메서드가 없어 AttributeError 발생
my_li = [1,2,3]
my_li.push(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7640e9daf84f> in <cell line: 3>()
#       1 # AttributeError: 존재하지 않는 속성이나 메서드를 호출 리스트엔 push라는 메서드가 없어 AttributeError 발생
#       2 my_li = [1,2,3]
# ----> 3 my_li.push(4)
#
# AttributeError: 'list' object has no attribute 'push'

# %%
# IOError 또는 OSError : 존재하지 않는 파일 열기 시도. 없어서 IOError 또는 OSError 발생
with open('non_existent_file.txt') as f:
  read_data = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-58b36672234c> in <cell line: 2>()
#       1 # IOError 또는 OSError : 존재하지 않는 파일 열기 시도. 없어서 IOError 또는 OSError 발생
# ----> 2 with open('non_existent_file.txt') as f:
#       3   read_data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %%
# ZeroDivisionError: 0으로 나눌 때 생긴다.
division = 10 / 0

# %%
# ImportError: 없는 모듈 임포트 시도
import non_existent_module

# %%
# StopIteration: 이터레이터가 더 이상 값을 제공 안함. 모든 값 소진한 이터레이터에 next() 호출
my_iter = iter(1,2,3)
next(my_iter)
next(my_iter)
next(my_iter)
next(my_iter) # 여기서 StopIteration 발생

# %%
# MemoryError: 매우 큰 메모리 할당 시도. 시스템 제공하는 메모리 용량을 초과하려 하면 MemoryError 발생
very_large = [0] * (10**10)

# %%
# RecursionError: 너무 깊은 재귀 호출 아무런 종료 조건 없이 계속 호출해서 파이썬의 최대 재귀 깊이에 도달할때까지 실행, 이 한계에 도달하면 RecursionError 발생
def recursive_function():
  recursive_function()
recursive_function()

# %%
#조건문으로 예외 처리
user_input = input('정수 : ')
if user_input.isdigit():
  num_input = int(user_input)
  print('반지름 : ', num_input)
else:
  print('정수 입력')
# Out:
# 정수 : ㅂㅂ
# 정수 입력

# %% [markdown]
# - 프로그램이 실행되는 동안 오류가 발생하면 프로그램이 더 이상 진행될 수 없는 상태가 되는데 이를 예외라고 함
# - 예외가 발생해도 프로그램을 중단하지 않고 예외에 대한 적절한 처리를 하여 프로그램을 계속 진행하도록 하는 구문이 try ~ except

# %% [markdown]
# ### 파이썬에서 예외 처리
# 프로그램 실행 중 발생할 수 있는 오류를 예상하고 관리할 수 있게 하는 강력한 기능이다. 이는 try, except, else, finally 블록을 사용해 수행된다. 각 구성 요소에 대해 간략히 설명하자면:
#
# - try: 이 코드 블록은 예외를 발생시킬 수 있는 연산을 포함한다. 코드가 오류를 일으킬 수 있다는 것을 "시도"하는 곳이다.
#
# - except: try 블록 내에서 오류가 발생하면, 파이썬은 그 블록의 실행을 멈추고 except 블록으로 점프한다. except 블록에서는 예외를 처리한다, 즉 오류에 대응하는 코드가 들어간다. 특정 예외를 이름으로 잡거나 모든 예외를 잡을 수 있다.
#
# - else: 이 블록은 선택적이며 try-except 블록 뒤에 올 수 있다. else 블록의 코드는 try 블록에서 예외가 발생하지 않았을 때만 실행된다. try 블록이 성공적으로 실행됐을 때만 실행되어야 하는 코드를 넣기에 적합하다.
#
# - finally: 이 블록은 선택적이지만, 존재한다면 예외 발생 여부와 관계없이 실행된다. 파일을 닫거나 리소스를 해제하는 등의 정리 작업을 위해 자주 사용된다. 이 작업들은 오류 발생 여부와 관계없이 수행되어야 한다.

# %% [markdown]
# #### 예외 처리 방법
# - try + except<br>
#   try : 에러가 발생할 것 같은, 예외처리를 하고 싶은 곳을 찾아서 try 구문에 코드를 작성합니다.<br>
#   except : 에러가 발생했을 때 처리할 코드를 작성합니다.
# - try + except + else<br>
#   else 는 에러가 발생하지 않았을때 거치는 구문입니다. else만 단독으로 try + else 는 불가능합니다. except 가 있어야 합니다.
# - try + finally<br>
#   finally 는 에러가 발생해도, 발생하지 않아도 무조건 거치는 구문입니다.except. 없이 try + finally 만 사용한다면 에러가 발생한 후에 finally 구문까지만 실행이 되고 프로그램이 중간에 죽게 됩니다.
# - try + except + finally
#   <br> except 구문을 추가하고 finally 구문도 있음
# - try + except + else + finally
#   <br> try (해당 구문 안에서 에러 발생 시 처리 가능 - 필수)
#   <br> except (에러 발생시 수행 - 선택이지만 에러를 처리하려면 필수)
#   <br> else (에러 없을 때 수행 - 선택이지만 except 없이는 올 수 없음)
#   <br> finally (에러가 있거나 없거나 상관없이 항상 수행 - 선택)

# %% [markdown]
# Q. 위의 예외애 대한 예외 처리

# %%
try:
  print(unknown_var) # 따옴표 있음 출력 가능
except NameError as e:
  print(f"An Error occured : {e}.")
# Out:
# An Error occured : name 'unknown_var' is not defined.

# %%
try:
  '2'+2
except TypeError as e:
  print(f"An Error occured : {e}.")
# Out:
# An Error occured : can only concatenate str (not "int") to str.

# %%
try:
  int('abc')
except ValueError as e:
  print(f"An Error occured : {e}.")
# Out:
# An Error occured : invalid literal for int() with base 10: 'abc'.

# %%
my_li = [1,2,3]
try:
  print(my_li[3])
except IndexError as e:
  print(f"An Error occured : {e}.")

# %%
my_dict = {'a':1,'b':2}
try:
  print(my_dict['c'])
except KeyError as e:
  print(f"The key wasn't found : {e}.")
# Out:
# The key wasn't found : 'c'.

# %%
# e:는 AttributeError만을 잡아내어 처리하고, e를 통해 오류에 대한 자세함 정보를 얻을 수 있다.

my_list = [1,2,3]
try:
  my_list.push(4)
except AttributeError as e:
  print(f"An Error occured : {e}.")
# Out:
# An Error occured : 'list' object has no attribute 'push'.

# %%
try:
  with open('non_existent_file.txt') as f:
    read_data = f.read()
except OSError as e:
  print(f"File Error : {e}.")
# Out:
# An Error occured : [Errno 2] No such file or directory: 'non_existent_file.txt'.

# %%
try:
  division = 10 / 0
except ZeroDivisionError as e:
  print(f"Math Error : {e}.")

# %%
try:
  import non_existent_module
except ImportError as e:
  print(f"Import Error : {e}")
# Out:
# Import Error : No module named 'non_existent_module'

# %%
my_iterator = iter([1,2,3])
try:
  while True:
    item = next(my_iterator)
    print(item)
except StopIteration:
  print("Reached the end of the iterator")
# Out:
# 1
# 2
# 3
# Reached the end of the iterator

# %% [markdown]
# Q. 예외처리 수행

# %%
arr = ['b', 'l', 'o', 'g']
try:
  print(arr[8])
except IndexError as e:
  print(f"list index out of range : {e}")

# %%
try:
  arr = ['b', 'l', 'o', 'g']
  print(arr[3])
except:
  print('예외 발생')
else:
  print('예외 미발생')
# Out:
# g
# 예외 미발생

# %%
print("== Program Start")
try:
  arr = ['b', 'l', 'o', 'g']
  print(arr[8])
finally:
  print("== finally")
print(" == Program End")

# %%
try:
  arr = ['b', 'l', 'o', 'g']
  print ("== Mid")
except:
  print('예외 발생')
finally:
  print('무조건 실행하는 코드')

# %% [markdown]
# Q. 위 코드에서 else를 추가하고

# %%
try:
  arr = ['b', 'l', 'o', 'g']
  print(arr[8])
  print ("== Mid")
except:
  print('예외 발생')
else:
  print('예외 미발생')
finally:
  print('무조건 실행하는 코드')
# Out:
# 예외 발생
# 무조건 실행하는 코드

# %% [markdown]
# Task1_0510. try ~ except, try ~ except ~ finally, try ~ except ~else, try ~ except ~else ~finally 4가지 예외 처리가 필요한 경우에 대해서 코딩을 수행하세요.

# %%
try:
  li2 = [1,2,3,4]
  for i in range(0,6):
    print(li2[i])
except IndexError as e:
  print('Error ')
finally:
  print('End')
# Out:
# 1
# 2
# 3
# 4
# Error
# End

# %%
try:
  ans = int(input("정수 "))
except:
  print('잘못 입력했습니다.')
# Out:
# 정수 1

# %%
try:
  ans = int(input("정수 "))
except:
  print('잘못 입력했습니다.')
finally:
  print('프로그램 종료')
# Out:
# 정수 ㅁ
# 잘못 입력했습니다.
# 프로그램 종료

# %%
try:
  ans = int(input("정수 "))
except:
  print('잘못 입력했습니다.')
else:
  print(f'행운의 숫자는 {ans+1}')
# Out:
# 정수 5
# 행운의 숫자는 6

# %%
try:
  ans = int(input("정수 "))
except:
  print('잘못 입력했습니다.')
else:
  print(f'행운의 숫자는 {ans-1}')
finally:
  print('프로그램 종료')
# Out:
# 정수 3
# 행운의 숫자는 2
# 프로그램 종료

# %% [markdown]
# Task2_0510. 리스트 ['52','273','32','문자','103']에서 숫자 부분만 출력하세요(예외 처리 수행)

# %%
lis =  ['52','273','32','문자','103']
for i in lis:
  try:
    (int(i))
  except:
    pass
  else:
    print(int(i))
# Out:
# 52
# 273
# 32
# 103

# %%
lis =  ['52','273','32','문자','103']
lis_num = []
for i in lis:
  int(i)
  lis_num.append(i)
print(lis_num)

# %%
lis =  ['52','273','32','문자','103']
lis_num = []
for i in lis:
  try:
    lis_num.append(int(i))
  except:
    pass
print(lis_num)
# Out:
# [52, 273, 32, 103]

# %% [markdown]
# Task3_0510. 두가지 시나리오를 예외처리를 하여 코드 작업을 수행하세요
# - 정수를 입력하면 > '예외 발생하지 않음' > '프로그램 종료'
# - 정수를 입력하지 않으면 > '정수 아님' > '프로그램 종료'

# %%
try:
  lnt = int(input(" "))
except:
  print('정수 아님')
else:
  print(lnt)
  print('정수')
finally:
  print('종료')
# Out:
#  aa
# 정수 아님
# 종료
